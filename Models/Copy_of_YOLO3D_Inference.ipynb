# %% [markdown]
# # YOLO3D Inference

# %% [markdown]
# ## Clone and Installation

# %%
# %cd /content/
# !rm -rf YOLO3D
# Out:
# /content

# %%
# %cd /content/
# !git clone https://github.com/ruhyadi/YOLO3D
# Out:
# /content
# Cloning into 'YOLO3D'...
# remote: Enumerating objects: 973, done.
# remote: Counting objects: 100% (340/340), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 973 (delta 169), reused 279 (delta 125), pack-reused 633
# Receiving objects: 100% (973/973), 24.83 MiB | 26.18 MiB/s, done.
# Resolving deltas: 100% (407/407), done.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# install requirements
# %cd /content/YOLO3D

# !pip install -q --upgrade --no-cache-dir gdown

# %%
# get weights
# %cd /content/YOLO3D/weights/
# !python get_weights.py --weights 'resnet18'
# Out:
# /content/YOLO3D/weights
# Downloading...
# From (original): https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn
# From (redirected): https://drive.google.com/uc?id=1k_v1RrDO6da_NDhBtMZL5c0QSogCmiRn&confirm=t&uuid=762685b7-d8f7-40af-a1e2-abb725ff0833
# To: /content/YOLO3D/weights/resnet18.pkl
# 100% 298M/298M [00:03<00:00, 96.9MB/s]

# %% [markdown]
# ## Inference

# %%
# %cd /content/YOLO3D/
# !python inference.py \
  --weights yolov5s.pt \
  --source /content/drive/MyDrive/scene5/video \
  --reg_weights weights/resnet18.pkl \
  --model_select resnet18 \
  --output_path runs02 \
  --save_result
# Out:
# /content/YOLO3D
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# inference: weights=['yolov5s.pt'], source=/content/drive/MyDrive/scene5/video, data=data/coco128.yaml, imgsz=[640, 640], device=, classes=[0, 2, 3, 5], reg_weights=weights/resnet18.pkl, model_select=resnet18, calib_file=eval/camera_cal/calib_cam_to_cam.txt, show_result=False, save_result=True, output_path=runs02
# ...

# %% [markdown]
# ## Show Result

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.cvtColor(cv2.imread('/content/YOLO3D/runs02/150.png'), cv2.COLOR_BGR2RGB)

plt.figure(figsize=(15, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from ultralytics import YOLO

# Load a pretrained pose model
model = YOLO('yolov8n-pose.pt')

# Predict keypoints on an image
results = model('path/to/your/image.jpg')

# Access keypoints
keypoints = results[0].keypoints
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-77a6b1a12834> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # Load a pretrained pose model
#       4 model = YOLO('yolov8n-pose.pt')
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
